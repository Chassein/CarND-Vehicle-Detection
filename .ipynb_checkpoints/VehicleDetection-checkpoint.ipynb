# %%
import numpy as np
import cv2
import glob
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# %%
kitti_images_name = glob.glob('data/vehicles/KITTI_extracted/*.png')
GTI_far_images_name = glob.glob('data/vehicles/GTI_Far/image*.png')
GTI_left_images_name = glob.glob('data/vehicles/GTI_Left/image*.png')
GTI_middle_images_name = glob.glob('data/vehicles/GTI_MiddleClose/image*.png')
GTI_right_images_name = glob.glob('data/vehicles/GTI_Right/image*.png')

GTI_name = glob.glob('data/non-vehicles/GTI/image*.png')
Extras_name = glob.glob('data/non-vehicles/Extras/extra*.png')


car_names = [kitti_images_name,GTI_far_images_name,GTI_left_images_name,GTI_middle_images_name,GTI_right_images_name]
non_car_names = [GTI_name,Extras_name]

# %%
car_images = []

for dataset_names in car_names:
    for name in dataset_names:
        image = cv2.cvtColor(cv2.imread(name),cv2.COLOR_BGR2RGB)
        car_images.append(image)
        
non_car_images = []

for dataset_names in non_car_names:
    for name in dataset_names:
        image = cv2.cvtColor(cv2.imread(name),cv2.COLOR_BGR2RGB)
        non_car_images.append(image)

# %%
plt.figure(1, figsize =(12,12))
plt.subplot(1,2,1)
plt.imshow(car_images[0])

plt.subplot(1,2,2)
plt.imshow(non_car_images[0])

# %%
print("Picture with Cars: " + str(len(car_images)))
print("Picture without Cars: " + str(len(non_car_images)))
# Out:
# Picture with Cars: 8792
# Picture without Cars: 8968

# %%
#Create Training Set Arrays with Labels

car_images = np.array(car_images)
non_car_images = np.array(non_car_images)

car_labels = np.ones(car_images.shape[0])
non_car_labels = np.zeros(non_car_images.shape[0])

X = np.concatenate((car_images,non_car_images),axis = 0)
y = np.concatenate((car_labels,non_car_labels),axis = 0)

#Shuffle the data set
X,y = shuffle(X,y)

# %%
#Save 20% as test data
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.2, random_state=1337)

#Save 20% as validation data
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, random_state=1337)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (10656, 64, 64, 3)
# (10656,)

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import cv2
import glob
import time
from sklearn.svm import LinearSVC
from sklearn.preprocessing import StandardScaler
from skimage.feature import hog
# NOTE: the next import is only valid for scikit-learn version <= 0.17
# for scikit-learn >= 0.18 use:
# from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split

# %%
from lesson_functions import *

# %%
color_space = 'RGB' # Can be RGB, HSV, LUV, HLS, YUV, YCrCb
orient = 9  # HOG orientations
pix_per_cell = 8 # HOG pixels per cell
cell_per_block = 2 # HOG cells per block
hog_channel = "ALL" # Can be 0, 1, 2, or "ALL"
spatial_size = (16, 16) # Spatial binning dimensions
hist_bins = 16    # Number of histogram bins
spatial_feat = True # Spatial features on or off
hist_feat = True # Histogram features on or off
hog_feat = True # HOG features on or off
y_start_stop = [360, 720] # Min and max in y to search in slide_window()
xy_window = [128,128]
xy_overlap = (0.75,0.75)

# %%
kitti_images_name = glob.glob('data/vehicles/KITTI_extracted/*.png')
GTI_far_images_name = glob.glob('data/vehicles/GTI_Far/image*.png')
GTI_left_images_name = glob.glob('data/vehicles/GTI_Left/image*.png')
GTI_middle_images_name = glob.glob('data/vehicles/GTI_MiddleClose/image*.png')
GTI_right_images_name = glob.glob('data/vehicles/GTI_Right/image*.png')

GTI_name = glob.glob('data/non-vehicles/GTI/image*.png')
Extras_name = glob.glob('data/non-vehicles/Extras/extra*.png')


car_names = [kitti_images_name,GTI_far_images_name,GTI_left_images_name,GTI_middle_images_name,GTI_right_images_name]
non_car_names = [GTI_name,Extras_name]

# Divide up into cars and notcars

cars = []
for dataset_names in car_names:
    for name in dataset_names:
        image = mpimg.imread(name)
        
        #Create 4 partial images
        w,h,_ =image.shape
        
        image_1 =image[:w//2,:h//2,:]
        image_2 =image[:w//2,h//2:,:]
        image_3 =image[w//2:,:h//2,:]
        image_4 =image[w//2:,h//2:,:]
        
        image = cv2.resize(image,(w//2,h//2))
        
        cars.append(image)
        cars.append(image_1)
        cars.append(image_2)
        cars.append(image_3)
        cars.append(image_4)
        
notcars = []
for dataset_names in non_car_names:
    for name in dataset_names:
         
        image = mpimg.imread(name)
        
        #Create 4 partial images
        w,h,_ =image.shape
        
        image_1 =image[:w//2,:h//2,:]
        image_2 =image[:w//2,h//2:,:]
        image_3 =image[w//2:,:h//2,:]
        image_4 =image[w//2:,h//2:,:]
        
        image = cv2.resize(image,(w//2, h//2))
        
        notcars.append(image)
        notcars.append(image_1)
        notcars.append(image_2)
        notcars.append(image_3)
        notcars.append(image_4)

# %%
plt.figure(1, figsize = (16,20))

carnumber = 100

plt.subplot(1,5,1)
plt.imshow(cars[5*carnumber])

plt.subplot(1,5,2)
plt.imshow(cars[5*carnumber+1])

plt.subplot(1,5,3)
plt.imshow(cars[5*carnumber+2])

plt.subplot(1,5,4)
plt.imshow(cars[5*carnumber+3])

plt.subplot(1,5,5)
plt.imshow(cars[5*carnumber+4])

# %%
t=time.time()
car_features = extract_features(cars, color_space=color_space, spatial_size = spatial_size, hist_bins=hist_bins, orient=orient, 
                        pix_per_cell=pix_per_cell, cell_per_block=cell_per_block, 
                        hog_channel=hog_channel)
notcar_features = extract_features(notcars, color_space=color_space, spatial_size = spatial_size, hist_bins=hist_bins, orient=orient, 
                        pix_per_cell=pix_per_cell, cell_per_block=cell_per_block, 
                        hog_channel=hog_channel)
t2 = time.time()
print(round(t2-t, 2), 'Seconds to extract HOG features...')
# Create an array stack of feature vectors
X = np.vstack((car_features, notcar_features)).astype(np.float64)                        
# Fit a per-column scaler
X_scaler = StandardScaler().fit(X)
# Apply the scaler to X
scaled_X = X_scaler.transform(X)

# Define the labels vector
y = np.hstack((np.ones(len(car_features)), np.zeros(len(notcar_features))))


# Split up data into randomized training and test sets
rand_state = np.random.randint(0, 100)
X_train, X_test, y_train, y_test = train_test_split(scaled_X, y, test_size=0.2, random_state=rand_state)

print('Using:',orient,'orientations',pix_per_cell,
    'pixels per cell and', cell_per_block,'cells per block')
print('Feature vector length:', len(X_train[0]))
# Use a linear SVC 
svc = LinearSVC()
# Check the training time for the SVC
t=time.time()
svc.fit(X_train, y_train)
t2 = time.time()
print(round(t2-t, 2), 'Seconds to train SVC...')
# Check the score of the SVC
print('Test Accuracy of SVC = ', round(svc.score(X_test, y_test), 4))
# Check the prediction time for a single sample
t=time.time()
n_predict = 10
print('My SVC predicts: ', svc.predict(X_test[0:n_predict]))
print('For these',n_predict, 'labels: ', y_test[0:n_predict])
t2 = time.time()
print(round(t2-t, 5), 'Seconds to predict', n_predict,'labels with SVC')
# Out:
# b:\anaconda\envs\tfgpu\lib\site-packages\skimage\feature\_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)
# 149.64 Seconds to extract HOG features...
# Using: 9 orientations 8 pixels per cell and 2 cells per block
# Feature vector length: 1788
# 248.77 Seconds to train SVC...
# Test Accuracy of SVC =  0.849
# My SVC predicts:  [ 1.  0.  1.  1.  1.  0.  0.  1.  1.  1.]
# For these 10 labels:  [ 1.  1.  1.  1.  1.  0.  0.  1.  1.  1.]
# 0.01562 Seconds to predict 10 labels with SVC

# %%
n_predict = y_test.shape[0]
t = time.time()
print('My SVC predicts: ', svc.predict(X_test[0:n_predict]))
print('For these',n_predict, 'labels: ', y_test[0:n_predict])
t2 = time.time()
print(round(t2-t, 5), 'Seconds to predict', n_predict,'labels with SVC')
# Out:
# My SVC predicts:  [ 1.  1.  0. ...,  1.  1.  0.]
# For these 3552 labels:  [ 1.  1.  0. ...,  1.  1.  0.]
# 0.04687 Seconds to predict 3552 labels with SVC

# %%
image = mpimg.imread('test_images/test1.jpg')
draw_image = np.copy(image)

# %%
# %matplotlib inline
plt.imshow(image)

# %%
from lesson_functions2 import *

# %%
windows = slide_window(image, x_start_stop=[None, None], y_start_stop=y_start_stop, 
                    xy_window=xy_window, xy_overlap=xy_overlap)

hot_windows = search_windows_32_32(image, windows, svc, X_scaler, color_space=color_space, 
                        spatial_size=spatial_size, hist_bins=hist_bins, 
                        orient=orient, pix_per_cell=pix_per_cell, 
                        cell_per_block=cell_per_block, 
                        hog_channel=hog_channel, spatial_feat=spatial_feat, 
                        hist_feat=hist_feat, hog_feat=hog_feat)                       

window_img = draw_boxes(draw_image, hot_windows, color=(0, 0, 255), thick=6)                    

plt.imshow(window_img)
# Out:
# b:\anaconda\envs\tfgpu\lib\site-packages\skimage\feature\_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)

# %%
windows2 = slide_window(image, x_start_stop=[None, None], y_start_stop=y_start_stop, 
                    xy_window=(64,64), xy_overlap=xy_overlap)

hot_windows2 = search_windows_32_32(image, windows2, svc, X_scaler, color_space=color_space, 
                        spatial_size=spatial_size, hist_bins=hist_bins, 
                        orient=orient, pix_per_cell=pix_per_cell, 
                        cell_per_block=cell_per_block, 
                        hog_channel=hog_channel, spatial_feat=spatial_feat, 
                        hist_feat=hist_feat, hog_feat=hog_feat)                       

window_img2 = draw_boxes(draw_image, hot_windows2, color=(0, 0, 255), thick=6)                    

plt.imshow(window_img2)
# Out:
# b:\anaconda\envs\tfgpu\lib\site-packages\skimage\feature\_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)

# %%
def add_heat(heatmap, bbox_list):
    # Iterate through list of bboxes
    for box in bbox_list:
        # Add += 1 for all pixels inside each bbox
        # Assuming each "box" takes the form ((x1, y1), (x2, y2))
        heatmap[box[0][1]:box[1][1], box[0][0]:box[1][0]] += 1

    # Return updated heatmap
    return heatmap

def apply_threshold(heatmap, threshold):
    # Zero out pixels below the threshold
    heatmap[heatmap <= threshold] = 0
    # Return thresholded map
    return heatmap

# %%
from scipy.ndimage.measurements import label

# %%
def draw_labeled_bboxes(img, labels):
    # Iterate through all detected cars
    for car_number in range(1, labels[1]+1):
        # Find pixels with each car_number label value
        nonzero = (labels[0] == car_number).nonzero()
        # Identify x and y values of those pixels
        nonzeroy = np.array(nonzero[0])
        nonzerox = np.array(nonzero[1])
        # Define a bounding box based on min/max x and y
        bbox = ((np.min(nonzerox), np.min(nonzeroy)), (np.max(nonzerox), np.max(nonzeroy)))
        # Draw the box on the image
        cv2.rectangle(img, bbox[0], bbox[1], (0,0,255), 6)
    # Return the image
    return img

# %%
plt.imshow(heat,'gray')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-afe1aa1f8c1d> in <module>()
# ----> 1 plt.imshow(heat,'gray')
#
# NameError: name 'heat' is not defined

# %%
# Apply threshold to help remove false positives
heat = apply_threshold(heat,1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-5a31b98ba63e> in <module>()
#       1 # Apply threshold to help remove false positives
# ----> 2 heat = apply_threshold(heat,1)
#
# NameError: name 'heat' is not defined

# %%
plt.imshow(heat,'gray')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-afe1aa1f8c1d> in <module>()
# ----> 1 plt.imshow(heat,'gray')
#
# NameError: name 'heat' is not defined

# %%
heat = np.zeros_like(image[:,:,0]).astype(np.float)
heat = add_heat(heat,hot_windows2)

heat = apply_threshold(heat,3)

heatmap = np.clip(heat, 0, 255)
labels = label(heatmap)
draw_img = draw_labeled_bboxes(np.copy(image), labels)
plt.imshow(draw_img)
